# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# [autoreload of IPython.core.interactiveshell failed: Traceback (most recent call last):
#   File "/Users/IXChris/anaconda/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ImportError: cannot import name skip_doctest_py2
# ]
# [autoreload of IPython.core.completer failed: Traceback (most recent call last):
#   File "/Users/IXChris/anaconda/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ImportError: cannot import name get_real_method
# ]
# [autoreload of IPython.lib.clipboard failed: Traceback (most recent call last):
#   File "/Users/IXChris/anaconda/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# AttributeError: 'module' object has no attribute 'utils'
# ]
# Traceback (most recent call last):
#
#   File "/Users/IXChris/anaconda/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 199, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#
#   File "/Users/IXChris/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2653, in run_cell
#
#   File "/Users/IXChris/anaconda/lib/python2.7/site-packages/IPython/core/inputsplitter.py", line 595, in transform_cell
#     self.reset()
#
#   File "/Users/IXChris/anaconda/lib/python2.7/site-packages/IPython/core/inputsplitter.py", line 527, in reset
#     super(IPythonInputSplitter, self).reset()
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
#df = pd.read_csv('data/COOLEY/')
path = !pwd
path = path[0]+'/data/'
path
# Out:
# '/Users/IXChris/Desktop/G/capstone/data/'

# %%
file_list = !ls data/COOLEY
file_list
# Out:
# ['venture_capital_deals_by_series.csv',
#  'venture_capital_median_pre-money_valuations_by_series.csv',
#  'venture_capital_percentage_of_up_rounds.csv',
#  'venture_capital_percentage_of_up_rounds_by_series.csv',
#  'venture_capital_total_deal_volume.csv']

# %%
file_list= [path+'COOLEY/'+x for x in file_list]
file_list
# Out:
# ['/Users/IXChris/Desktop/G/capstone/data/COOLEY/venture_capital_deals_by_series.csv',
#  '/Users/IXChris/Desktop/G/capstone/data/COOLEY/venture_capital_median_pre-money_valuations_by_series.csv',
#  '/Users/IXChris/Desktop/G/capstone/data/COOLEY/venture_capital_percentage_of_up_rounds.csv',
#  '/Users/IXChris/Desktop/G/capstone/data/COOLEY/venture_capital_percentage_of_up_rounds_by_series.csv',
#  '/Users/IXChris/Desktop/G/capstone/data/COOLEY/venture_capital_total_deal_volume.csv']

# %%
df = pd.concat(pd.read_csv(f).set_index('Date') for f in file_list)
#df = pd.read_csv(file_list[0]).set_index('Date')

df2 = pd.read_csv(file_list[1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 2003-12-31 to 2016-03-31
# Data columns (total 11 columns):
# Amount Raised             49 non-null float64
# Number of Deals           44 non-null float64
# Series A                  51 non-null float64
# Series A (%)              79 non-null float64
# Series B                  51 non-null float64
# Series B (%)              79 non-null float64
# Series C                  51 non-null float64
# Series C (%)              79 non-null float64
# Series D (%) or Higher    79 non-null float64
# Series D or Higher        51 non-null float64
# Value (%)                 50 non-null float64
# dtypes: float64(11)
# memory usage: 21.5+ KB

# %%
df.describe()
# Out:
#        Amount Raised  Number of Deals   Series A  Series A (%)   Series B  \
# count      49.000000        44.000000  51.000000     79.000000  51.000000
# mean     1447.102041       104.181818   8.219608     33.103544  26.790196
# std       815.307975        23.517705   4.067088     36.038608  13.285455
# min       703.000000        60.000000   3.000000      0.250000  11.600000
# 25%              NaN              NaN        NaN           NaN        NaN
# 50%              NaN              NaN        NaN           NaN        NaN
# 75%              NaN              NaN        NaN           NaN        NaN
# max      3900.000000       189.000000  19.000000    100.000000  70.000000
#
#        Series B (%)    Series C  Series C (%)  Series D (%) or Higher  \
# count     79.000000   51.000000     79.000000               79.000000
# mean      32.355823   50.188235     27.332152               25.170633
# std       36.899259   23.857424     34.318040               31.596792
# min        0.200000   22.000000      0.100000                0.000000
# 25%             NaN         NaN           NaN                     NaN
# 50%             NaN         NaN           NaN                     NaN
# 75%             NaN         NaN           NaN                     NaN
# max       96.000000  125.000000    100.000000               92.000000
#
#        Series D or Higher  Value (%)
# count           51.000000  50.000000
# mean            99.566667  20.433800
# std             77.042260  35.681959
# min             13.000000   0.160000
# 25%                   NaN        NaN
# 50%                   NaN        NaN
# 75%                   NaN        NaN
# max            400.000000  91.000000

# %%
pd.scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a251990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a441910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a602990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a664bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a6e7d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a73da10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a7caf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a94af10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a9b8cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aa47190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aa9cf50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11ac2b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aad6050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11acf0350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ad692d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11adc6190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ae48110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aea2ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b038110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b0bb090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b11bb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b19ea90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b303bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b384b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b391f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b474b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b4f6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b55ae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b5dbe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b743c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b7ccd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b84dcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b8bc910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b93f890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b9a39d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb23a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb32e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc12a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc96990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bce29d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd67510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd96710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be636d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bee4750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bf497d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bfc9850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c130610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c1b1690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c1ea850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c2a0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c423690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c4868d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c508850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c56f650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c5f8850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c7797d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c7e9290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c86c210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8d0350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c9502d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c989210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca402d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cac2250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cc27610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cca8590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cd11390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11cd82d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ce11590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ce71f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf01210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf4dad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cfdbcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d15cc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1cbdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d34cd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d3bc8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d449110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d495c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d621c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d6a5c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d711f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d793e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e003a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e092250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e0e0d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e26add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e2efd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e36a090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e3ddfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e44db50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e4dc390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d37bed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e6a2750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e727510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e791d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f1213d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f186250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f2072d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f19dd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f2f8550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f47a3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f4dcad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f55e6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f5ce890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f75c3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f712890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f841cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f8c4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa32690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fab5610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fb184d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fb9c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fbd4610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fc8b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd0f490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd72790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fdf4710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe5b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fee5710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120068690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1200d7150>]], dtype=object)

# %%
df2
# Out:
#           Date  Series A  Series B  Series C  Series D or Higher
# 0   2003-09-30       4.5      15.0      25.3                48.5
# 1   2003-12-31       7.0      15.0      41.0                13.0
# 2   2004-03-31       3.8      18.5      27.6                50.0
# 3   2004-06-30       3.0      15.0      34.1                46.0
# 4   2004-09-30       5.6      15.0      23.0                29.0
# 5   2004-12-31       6.0      16.0      28.0                61.0
# 6   2005-03-31       7.8      15.0      24.3                50.0
# 7   2005-06-30       5.0      32.0      27.7                32.5
# 8   2005-09-30       5.0      12.0      24.0                35.0
# 9   2005-12-31       4.0      15.5      46.5                50.0
# 10  2006-03-31       6.4      23.0      85.0               105.0
# 11  2006-06-30       6.0      26.0      43.0                65.0
# 12  2006-09-30       5.0      25.0      42.0               100.0
# 13  2006-12-31       5.0      27.0      45.0                70.0
# 14  2007-03-31       6.8      25.0      40.0                40.0
# 15  2007-06-30       7.0      24.0      45.0                80.0
# 16  2007-09-30       4.5      20.0      37.0                97.0
# 17  2007-12-31       6.0      22.0      62.0                78.0
# 18  2008-03-31       9.0      24.0      43.0                92.5
# 19  2008-06-30       4.8      24.5      40.0                57.0
# 20  2008-09-30       7.0      20.0      65.5                90.0
# 21  2008-12-31       7.4      16.5      25.0                50.0
# 22  2009-03-31       3.4      13.9      26.7                30.3
# 23  2009-06-30       4.8      17.0      34.0                58.8
# 24  2009-09-30       7.5      11.6      22.0                65.0
# 25  2009-12-31       6.0      20.3      30.0                50.5
# 26  2010-03-31       6.5      18.5      32.0                50.0
# 27  2010-06-30       7.2      15.5      48.4                45.0
# 28  2010-09-30       8.0      26.0      32.0                45.0
# 29  2010-12-31       5.5      16.5      47.5               157.5
# 30  2011-03-31       6.0      15.0      54.0                61.0
# 31  2011-06-30       7.0      25.0      48.0               106.0
# 32  2011-09-30      10.0      31.0      42.0               110.0
# 33  2011-12-31       9.0      25.0      54.0               100.0
# 34  2012-03-31       7.5      31.0      55.0                62.3
# 35  2012-06-30       8.5      35.0      44.0                90.0
# 36  2012-09-30       6.7      22.0      65.0               105.0
# 37  2012-12-31       8.0      30.0      32.0               215.0
# 38  2013-03-31      11.0      16.0      28.0               106.0
# 39  2013-06-30       8.0      37.0     125.0                77.0
# 40  2013-09-30       8.0      26.0      60.0               170.0
# 41  2013-12-31      10.0      39.0      67.0                75.0
# 42  2014-03-31      14.0      44.0      92.0               131.0
# 43  2014-06-30      16.0      40.0     115.0               140.0
# 44  2014-09-30      15.0      33.0      85.0               175.0
# 45  2014-12-31      16.0      43.0      77.0               146.0
# 46  2015-03-31      13.0      59.0      65.0               128.0
# 47  2015-06-30      17.0      49.0      60.0               345.0
# 48  2015-09-30      19.0      56.0      80.0               400.0
# 49  2015-12-31      16.0      70.0      80.0               266.0
# 50  2016-03-31      18.0      55.0      85.0               228.0

# %%
df2

# %%
Data include number of firms, number of establishments, employment, 
annual payroll, and estimated receipts by enterprise employment size. 
The industry classification is based on Standard Industrial Classification 
(SIC) codes. An establishment with 0 employment is an establishment with no paid 
employees in the mid-March pay period but with paid employees at some time during the year.
